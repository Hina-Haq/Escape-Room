# %%
game_state = {
    "current_room": "game_room",
    "keys_collected": [],
    "unlocked_doors": []
}

rooms = {
    "game_room": {
        "objects": ["couch", "piano", "door a"],
        "items_keys": {"piano": "key a"}
    },
    "bedroom 1": {
        "objects": ["queen bed", "door a", "door b", "door c"],
        "items_keys": {"queen bed": "key b"}
    },
    "bedroom 2": {
        "objects": ["double bed", "dresser", "door b"],
        "items_keys": {"double bed": "key c", "dresser": "key d"}
    },
    "living room": {
        "objects": ["dining table", "door c", "door d"],
        "items_keys": {}
    }
}

doors = {
    "door a": {"rooms": ["game room", "bedroom 1"], "key": "key a"},
    "door b": {"rooms": ["bedroom 1", "bedroom 2"], "key": "key b"},
    "door c": {"rooms": ["bedroom 1", "living room"], "key": "key c"},
    "door d": {"rooms": ["living room", "outside"], "key": "key d"}
}


def play_game():
    print("Welcome to the Escape Room Game!")
    print("You find yourself in a mysterious house with several rooms. Your goal is to find the keys, unlock the doors, and escape the house.")
    print("You have 3 types of commands: 'explore', 'examine', and 'go'.")
    current_room_id = game_state["current_room"]
    current_room = rooms[current_room_id]
    action = input("What would you like to do? (explore / examine [object] / go [door]): ").lower().strip()

if __name__ == "__main__":
    play_game()
